# %% [markdown]
# # <font color='blue'>Chapter 9. Fourier Series and Transform</font>

# %% [markdown]
# ## <font color='blue'>Problem</font>

# %% [markdown]
# ### Visualize Fourier transform
# https://www.youtube.com/watch?v=spUNpyF58BY&t=265s <br>
#
# ### Fourier Transform, Fourier Series, and frequency spectrum
# https://www.youtube.com/watch?v=r18Gi8lSkfM
#
# ### The intuition behind Fourier and Laplace transforms I was never taught in school
# https://www.youtube.com/watch?v=3gjJDuCAEQQ

# %% [markdown]
# ### <font color='green'>Next: Z Transform</font>

# %% [markdown]
# ### <font color='blue'>Euler number defintion</font>
# For Compound interest,
#
# Let the principal is $a$, then the interest will be doubled in one unit time with the compound interest to be $a(1+1)^1$
#
# If the interest is gievn in half in a half unit, then the compound interest will be $a(1+\frac{1}{2})^2$
#
# In general, the formula will be $a(1+\frac{1}{n})^n$
# \begin{equation}
# \begin{split}
# e = \lim_{n\to \infty} (1 + \frac {1}{n})^n \approx 2.71828
# \end{split}
# \end{equation}

# %% [markdown]
# ### <font color='blue'>Euler's Identity (歐拉恆等式)</font>
# https://www.youtube.com/watch?v=sKtloBAuP74
# \begin{equation}
# \begin{split}
# e^\theta = 1 + \frac{\theta}{1!} + \frac{\theta^2}{2!} + \frac{\theta^3}{3!} + ...
# \end{split}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \begin{split}
# e^{j\theta} = \cos \theta + j \sin \theta
# \end{split}
# \end{equation}
# where $\sin \theta = \frac{e^{j \theta}-e^{-j \theta}}{2 j}$, and  $\cos \theta = \frac{e^{j \theta}+e^{-j \theta}}{2}$

# %% [markdown]
# If $\theta = \pi$, then $e^{j\pi} = \cos \pi + j \sin \pi = -1 $. Then, we have $e^{j\pi} + 1 = 0 $.

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="200"/>
# </div>
# source: https://zh.wikipedia.org/wiki/%E6%AD%90%E6%8B%89%E6%81%86%E7%AD%89%E5%BC%8F

# %% [markdown]
# ## <font color='blue'>9-1 Fourier Series </font>
# Basic concept: Given an any period function, it can be represented as a series of different frequencies and amplitudes of sin and cos functions. <br>
#     The series is named Fourier Series.
#
# https://www.khanacademy.org/science/electrical-engineering/ee-signals/ee-fourier-series/v/ee-fourier-series-intro

# %% [markdown]
# ### Fourier Series
# If a function $x(t)$ is defined between intervals $ –L \leq t \leq L$, then the Fourier Series can be defined as:
#
# \begin{equation}
# x(t)=\frac{1}{2}a_0 + \sum_{n=1}^{\infty} [a_n \cos \frac{n \pi t}{L} +  b_n \sin \frac{n \pi t}{L}]
# \end{equation}
#
# where
#
# \begin{equation}
# a_0=\frac{1}{L} \int_{-L}^{L}x(t)dt \\
# a_n=\frac{1}{L} \int_{-L}^{L}x(t)\cos \frac{n \pi t}{L}dt \\
# b_n=\frac{1}{L} \int_{-L}^{L}x(t)\sin \frac{n \pi t}{L}dt
# \end{equation}

# %% [markdown]
# In this series, $\frac{1}{2}a_0$ is a constant, and $a_n$ and $b_n$ can be considered as the amplidudes of the nth sinsouid with the corresponding frequency $n \omega$.  <br>
# Therefore, we can decompose the componments of the series into DC componment and AC componment. <br>
# That is, $x(t) = DC + AC $ <br>
# where <br>
# $ DC =\frac{1}{2}a_0 $ <br>
# $ AC =\sum_{n=1}^{\infty} [a_n \cos \frac{n \pi t}{L} +  b_n \sin \frac{n \pi t}{L}] $

# %% [markdown]
# #### Expample:
# If a function is defined as
# \begin{equation}
#   x(t) =
#     \begin{cases}
#       -1, & \text {if}\; -1 < t < 0\\
#       1, & \text {if}\; 0 \leq t < 1
#     \end{cases}
# \end{equation}
# ![image.png](attachment:image.png)

# %% [markdown]
# Assume $x(t)$ is a periodic function, it meets $x(t) = x(t + 2)$.
# Hence, it will form a idal square wave if extending left and right to infinite <br>
# Period $T = 2 $(or $L = 1$). First, the process for finding terms of Fourier Series is as follows.
# \begin{equation}
# a_0=\frac{1}{L} \int_{-L}^{L}x(t)dt = \int_{-1}^{1}x(t)dt = \int_{-1}^{0}(-1)dt+\int_{0}^{1}(1)dt =0\\
# \end{equation}

# %% [markdown]
# \begin{equation}
# \begin{split}
# a_n &= \frac{1}{L} \int_{-L}^{L}x(t)\cos \frac{n \pi t}{L}dt\\
#     &= \int_{-1}^{1}x(t)\cos {n \pi t}dt \\
#     &= \int_{-1}^{0}(-1)\cos {n \pi t}dt + \int_{0}^{1}(1)\cos {n \pi t}dt \\
#     &= [-\frac{1}{n \pi} \sin(n \pi t) ]_{-1}^{0} + [\frac{1}{n \pi} \sin(n \pi t) ]_{0}^{1}=0
# \end{split}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \begin{split}
# b_n &= \frac{1}{L} \int_{-L}^{L}x(t)\sin \frac{n \pi t}{L}dt\\
#     &= \int_{-1}^{1}x(t)\sin {n \pi t}dt \\
#     &= \int_{-1}^{0}(-1)\sin {n \pi t}dt + \int_{0}^{1}(1)\sin {n \pi t}dt \\
#     &= [\frac{1}{n \pi} \cos(n \pi t) ]_{-1}^{0} + [-\frac{1}{n \pi} \cos(n \pi t) ]_{0}^{1} \\
#     &= \frac{2}{n\pi}-\frac{2}{n\pi}\cos(n\pi) \\
#     &= \frac{2}{n\pi}[1-(-1)^n]
# \end{split}
# \end{equation}

# %% [markdown]
# Therefore, the $x(t)$ in Fourier Series will be
# \begin{equation}
# \begin{split}
# x(t) &= \frac{1}{2}a_0 + \sum_{n=1}^{\infty} [a_n \cos \frac{n \pi t}{L} +  b_n \sin \frac{n \pi t}{L}] \\
#      &= \sum_{n=1}^{\infty} \frac{2}{n\pi}[1-(-1)^n] \sin (n \pi t) \\
#      &= \frac{4}{\pi}\sin (\pi t) +\frac{4}{3\pi}\sin (3\pi t) +...
# \end{split}
# \end{equation}

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="300"/>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

N = eval( input( "Please enter number of terms for partial sum: " ) )

t = np.linspace( -1, 1, 1000 )	# 

x = np.zeros( 1000 )			# 
for n in range( 1, N + 1 ):
	x += 2 / ( n * np.pi ) * ( 1 - np.power( -1, n ) ) * np.sin( n * np.pi * t ) 


plt.figure(figsize=(5, 4), dpi=60)
plt.plot( t, x )								
plt.xlabel( 't (second)' )
plt.ylabel( 'Amplitude' )

plt.show( )
# Out:
# Please enter number of terms for partial sum: 10000

# %% [markdown]
# ## <font color='blue'>9-2 Fourier Transform </font>
# ### Imaginary Numbers Are Real [Part 1: Introduction]
# https://www.youtube.com/watch?v=T647CGsuOVU
#
# ### Complex Numbers - Powers of i | Don't Memorise
# https://www.youtube.com/watch?v=KTNcYYHuBTY

# %% [markdown]
# The Fourier Transform of a function $x(t)$ can be defined as
# \begin{equation}
# X(\omega)=F\{ x(t)\}=\int_{-\infty}^{\infty} x(t)e^{-j \omega t} dt
# \end{equation}

# %% [markdown]
# The Inverse Fourier Transform of a function $X(\omega)$ can be defined as
# \begin{equation}
# x(t)=F^{-1}\{ X(\omega)\}=\frac{1}{2\pi}\int_{-\infty}^{\infty} X(\omega)e^{j \omega t} d\omega
# \end{equation}

# %% [markdown]
# where $\int_{-\infty}^{\infty} |x(t)|dt$ is convergence with $j=\sqrt{-1}$

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# #### Example. 2
# Find the Fourier Transform of function given as $x(t)=Acos(\omega_0 t+\phi)$, <br>
# where A, $\omega_0$, and $\phi$ are amplitude, angular frequency, and phase shift, respectively.

# %% [markdown]
# \begin{equation}
# \begin{split}
# X(\omega) &= F\{ x(t) \} =\int_{-\infty}^{\infty} x(t) e^{-j \omega t} dt \\
#           &= \int_{-\infty}^{\infty} A \cos (\omega_0 t) e^{-j \omega t} dt \\
#           &= A \int_{-\infty}^{\infty} (\frac { e^{j \omega_0 t} + e^{-j \omega_0 t}}{2})e^{-j \omega t} dt \\
#           &= \frac{A}{2}[\int_{-\infty}^{\infty} e^{j \omega_0 t}e^{-j \omega t}dt + \int_{-\infty}^{\infty} e^{-j \omega_0 t}e^{-j \omega t}dt]\\
#           &= \frac{A}{2}[F\{ e^{j \omega_0 t} \} + F \{ e^{-j \omega_0 t} \}]\\
#           &= A \pi [\delta(\omega-\omega_0)+ \delta(\omega+\omega_0)]
# \end{split}
# \end{equation}
# where, $F\{e^{j \omega_0 t }\} = 2 \pi \delta (\omega-\omega_0)$

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="300"/>
# </div>

# %% [markdown]
# #### Example. 3
# If a function is defined as
# \begin{equation}
#   x(t) =
#     \begin{cases}
#       A, & \text {if}\; -T/2 < t < T/2\\
#       0, & \text {otherwise}\;
#     \end{cases}
# \end{equation}
# is called ideal pulse function, find the Fourier transform

# %% [markdown]
# \begin{equation}
# \begin{split}
# X(\omega) &= \int_{-\infty}^{\infty} x(t) e^{-j \omega t} dt = \int_{-T/2}^{T/2} A e^{-j \omega t} dt \\
#           &= A \int_{-T/2}^{T/2} e^{-j \omega t} dt \\
#           &= A [-\frac{1}{j\omega} e^{-\frac{j\omega T}{2}} + \frac{1}{j\omega} e^{\frac{j\omega T}{2}}] \\
#           &= \frac{A}{j\omega} [e^{\frac{j\omega T}{2}} - e^{-\frac{j\omega T}{2}}]\\
#           &= \frac{A}{j\omega} [\cos (\frac{\omega T}{2})+j\sin (\frac{\omega T}{2})-\cos (\frac{\omega T}{2})+j\sin (\frac{\omega T}{2})] \\
#           &= \frac{A}{\omega}[2\sin (\frac{\omega T}{2})] = AT[\frac{\sin(\frac{\omega T}{2})}{\frac{\omega T}{2}}]\\
#           &= AT \cdot sinc(\frac{\omega T}{2 \pi})
# \end{split}
# \end{equation}

# %%
import numpy as np
import matplotlib.pyplot as plt

A = 0.1
T = 0.000001
w = np.linspace( -200, 200, 10000 )
X = A * T * np.sinc( w * T / ( 2 * np.pi ) )

plt.figure(figsize=(5, 4), dpi=60)
plt.plot( w, X )
plt.xlabel( r'$\omega$' )
plt.ylabel( r'X($\omega$)' )

plt.show( )

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# ### Fourier Transform Shifting Theorems (傅立葉轉換的平移定理)：
# #### (1) First Shifting Theorem (第一平移定理)
#
# If $f$ is a time function, and $F$ is its Fourier Transform. Then,
# \begin{equation}
# F\{ f(t-t_0)\}= F(\omega) e^{-j \omega t_0}
# \end{equation}
#
# Where $t_0$ is the shifting time and $t_0 > 0$
#
# \begin{equation}
# F\{ f(t-t_0)\}= \int_{-\infty}^{\infty} f(t-t_0) e^{-j \omega t} dt
# \end{equation}
# let $\tau = t - t_0 $, then $t=\tau + t_0$, and $d\tau=dt$ <br>
# we have
#
# \begin{equation}
# \begin{split}
# F\{ f(t-t_0)\} &= \int_{-\infty}^{\infty} f(\tau) e^{-j \omega (\tau+t_0)} d\tau\\
#                &= \int_{-\infty}^{\infty} f(\tau) e^{-j\omega \tau} \cdot e^{-j\omega t_0} d\tau\\
#                &= F(\omega) \cdot e^{-j\omega t_0}
# \end{split}
# \end{equation}

# %% [markdown]
# #### (2)The Second Shifting Theorem (第二平移定理)
#
# If $f$ is a time function, and $F$ os its Fourier Transform. Then,
# \begin{equation}
# F\{ f(t) \cdot e^{j\omega_0 t}\}= F(\omega - \omega_0)
# \end{equation}
#
# where $\omega_0$ is the shifting angular Frequency (平移角頻率) and $ \omega_0 > 0$
#
# \begin{equation}
# F\{ f(t) \cdot e^{j\omega_0 t}\}= \int_{-\infty}^{\infty}f(t)\cdot e^{j \omega_0 t} \cdot e^{-j \omega t} dt
# = \int_{-\infty}^{\infty}f(t)\cdot e^{j (\omega - \omega_0)t} dt = F(\omega - \omega_0)
# \end{equation}

# %% [markdown]
# #### (3)捲積定理
#
# 若$f$與$g$為兩個時間的函數，且$F$為傅立葉轉換，則：
#
# \begin{equation}
# F\{ f*g \}= F\{f\}*F\{g\}
# \end{equation}
#
# 其中，星號*為卷積運算。

# %% [markdown]
# #### (4)高斯函數的傅立葉轉換
#
# 高斯函數的傅立葉轉換，形成另一個高斯函數：
# \begin{equation}
# F\{\ e^{-\frac{t^2}{2 \sigma^2}}\}= \sqrt{2\pi \sigma^2} \cdot e^{-\frac{t^2}{2 \sigma^2}}
# \end{equation}
#
# 其中，$\sigma$為標準差。

# %% [markdown]
# #### Example
# 若高斯函數是定義為：
#
# $x(t)=e^{-\frac{t^2}{2 \sigma^2}}$
#
# 其中，標準差 $\sigma$ =1, 2, 3，則時間域的高斯函數與其在頻率域的傅立葉轉換各為何?
# 由圖可以發現，兩個高斯函數的標準差之間，形成反比關係

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>
# <div>
# <img src="attachment:image2.png" width="500"/>
# </div>

# %% [markdown]
# #### gaussian_Fourier_transform

# %%
import numpy as np
import matplotlib.pyplot as plt

sigma = eval( input( "Enter sigma: " ) )

t = np.linspace( -7, 7, 100 )
x = np.exp( - ( t * t ) / ( 2 * sigma * sigma ) )

w = np.linspace( -7, 7, 1000 )
X = np.exp( - ( sigma * sigma * w * w ) / 2 )
X = np.sqrt( 2 * np.pi * sigma * sigma ) * X

plt.figure(figsize=(5, 4), dpi=60)
plt.figure( 1 )
plt.plot( t, x )
plt.xlabel( 't' )
plt.ylabel( 'x(t)' )

plt.figure(figsize=(5, 4), dpi=60)
plt.figure( 2 )
plt.plot( w, X )
plt.xlabel( r'$\omega$' )
plt.ylabel( r'X($\omega$)' )

plt.show( )
# Out:
# Enter sigma: 1.96

# %% [markdown]
# ## <font color='blue'>9-3 離散時間傅立葉轉換 </font>
# 給定離散的序列$x[n]$，則離散時間傅立葉轉換(Discrete-Time Fourier Transform, DTFT)可以定義為：
#
# \begin{equation}
# X(e^{j\omega}) = \sum_{n=-\infty}^{\infty} x[n]e^{-j \omega n}
# \end{equation}
#
# 反離散時間傅立葉轉換(Inverse DTFT)可以定義為：
#
# \begin{equation}
# x[n] = \frac{1}{2\pi} \int_{-\infty}^{\infty} X(e^{j \omega})e^{j \omega n} d\omega
# \end{equation}

# %% [markdown]
# In general, $X(e^{j \omega})$ is a function of $\omega$ that can be represented as
#
# \begin{equation}
# X(e^{j\omega}) = |X(e^ {j\omega})| \cdot e^ {j \theta(\omega)}
# \end{equation}
#
# where $|X(e^ {j\omega})|$ is magnitude (強度), and $\theta(\omega)$ is argument (幅角) or phase angle (相位角).
#
# Also, if a discrete-time sequence is absolutely summable sequence, then
# \begin{equation}
# \sum_{n=-\infty}^{\infty} |x[n]| < \infty
# \end{equation}
# Then, we have
# \begin{equation}
# |X(e^{j\omega})| < \infty, \text{for all } \omega
# \end{equation}

# %% [markdown]
# #### Example.
# 若數位訊號 $x[n]$為：
# \begin{equation}
# x[n]=\delta [n]
# \end{equation}
# or
# \begin{equation}
# x[n]=(0.5)^n u[n]
# \end{equation}
# 其中，$\delta [n]$與$u[n]$分別為單位脈衝與單位步階，求離散時間傅立葉轉換(DTFT)。

# %% [markdown]
# Sol. (unit pulse)
# \begin{equation}
# |X(e^{j\omega})| = \sum_{n=-\infty}^{\infty} x[n] \cdot e^{-j\omega n} = \sum_{n=-\infty}^{\infty}\delta[n] \cdot e^{-j\omega n}=1
# \end{equation}

# %% [markdown]
# Sol. (unit step)
#
# If $\sum_{n=-\infty}^{\infty} |x[n]| < \infty $, then we have

# %% [markdown]
# \begin{equation}
# \begin{split}
# |X(e^{j\omega})| &= \sum_{n=-\infty}^{\infty} x[n] \cdot e^{-j\omega n} \\
#                  &= \sum_{n=-\infty}^{\infty} (0.5)^n u[n] \cdot e^{-j\omega n} \\
#                  &= \sum_{n=0}^{\infty} (0.5)^n \cdot e^{-j\omega n} \\
#                  &= \sum_{n=0}^{\infty} (0.5 e^{-j\omega})^n=\frac{1}{1-0.5 e^{-j\omega}}
# \end{split}
# \end{equation}

# %% [markdown]
# ## <font color='blue'>9-4 DFT (離散傅立葉轉換)</font>
# Performing the DFT Using Basic Math<br>
# If we have an L-sample-long sequence, $x[n]$, representing the analog continuous-time signal $x(t)$.
# The goal is to find a set of sinusoids which can be added together to produce $x[n]$.
#
# The DFT is based on sampling the DTFT, given by Equation 23, at equally spaced frequency points. $X(e^{jω})$ is a periodic function in
# $ω$ with a period of 2π. If we take $N$ samples in each period of $X(e^{jω})$, the spacing between frequency points will be
# $\frac{2π}{N}$.
#
# Hence, the frequency of the set of sinusoids that we are looking for will be of the form $\frac{2π}{N}k$, where we can select
# $k=0,1,...,N−1$. Using complex exponentials similar to Equation 23 and 24, the basis functions will be the form $\frac{2π}{N}k$.
# We are looking for a weighted sum of these functions which will hopefully give us the original signal $x[n]$.
# This means that

# %% [markdown]
# \begin{equation}
# x[n] = \sum_{k=0}^{N-1} X[k]e^{j \frac{2\pi}{N}kn}, n=0, 1,..., L-1
# \end{equation}
#
# where $X′(k)$ denotes the weight used for the complex exponential $e^{j \frac{2\pi}{N}kn}$.

# %% [markdown]
# Equation 32 is equivalent to the following set of equations
#
# \begin{equation}
# \begin{split}
# x[0] &= X'[0] + X'[1] + X'[2] +...+  X'[N-1] \\
# x[1] &= X'[0] + X'[1]e^{j \frac{2\pi}{N}} + X'[2]e^{j \frac{2\pi}{N}2} +...+  X'[N-1]e^{j \frac{2\pi}{N}(N-1)} \\
# x[2] &= X'[0] + X'[1]e^{j \frac{2\pi}{N}2} + X'[2]e^{j \frac{2\pi}{N}2 \cdot 2} +...+  X'[N-1]e^{j \frac{2\pi}{N}(N-1)\cdot 2}\\
# ... \\
# x[L-1] &= X'[0] + X'[1]e^{j \frac{2\pi}{N}(L-1)} + X'[2]e^{j \frac{2\pi}{N}2(L-1)} +...+  X'[N-1]e^{j \frac{2\pi}{N}(N-1)(L-1)}\\
# \end{split}
# \end{equation}

# %% [markdown]
# For a given $L$ and $N$, the values of complex exponentials are known and, having the value of the time-domain signal,
# we can calculate the coefficients $X′[k]$. The number of time-domain samples, $L$,
# gives the number of equations in the above set of equations, and the number of frequency-domain samples of $X(e^{jω})$
# determines the number of unknowns in Equation 33. With $L=N$, there are $N$ linearly independent equations to find the
# $N$ unknowns, $X′[k]$.

# %% [markdown]
# Given a discrete time series $x[n], n=0, 1,..., N-1$, then the Discrete Fourier Transform (DFT) can be defined as:
#
# \begin{equation}
# X[k] = \sum_{n=0}^{N-1} x[n]e^{-j \frac{2\pi}{N} kn}, k=0, 1,..., N-1
# \end{equation}
#
# The Inverse DFT can be defined as:
#
# \begin{equation}
# x[n] = \frac{1}{N} \sum_{k=0}^{N-1} X[k] e^{j \frac{2\pi}{N}kn}, n=0, 1,..., N-1
# \end{equation}

# %% [markdown]
# It comes from the samples at $\omega$ axis with $\omega= \frac{2\pi}{N} k$
#
# $X[k] = X(j\omega)|_{\omega= \frac{2\pi}{N} k} = \sum_{n=0}^{N-1} x[n] e^{-j\frac{2\pi}{N} kn} $

# %% [markdown]
# Therefore, DFT also can be defined as
#
# \begin{equation}
# X[k] = \sum_{n=0}^{N-1} x[n] W_{N}^{kn}, k=0, 1,..., N-1
# \end{equation}
#
# 反離散傅立葉轉換(Inverse DFT)可以定義為：
#
# \begin{equation}
# x[n] = \frac{1}{N} \sum_{k=0}^{N-1} X[k] W_{N}^{kn},n=0, 1,..., N-1
# \end{equation}
#
# where $ W_{N} = e^{-j (2 \pi/N)}$

# %% [markdown]
# #### Example
# 若數位訊號定義為：$x[n]={1, 2, 4, 3}$， 求離散傅立葉轉換(DFT)。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sol.
# \begin{equation}
# \begin{split}
# X[k] &= \sum_{n=0}^{N-1} x[n] \cdot e^{-j2 \pi kn/N} \\
# X[0] &= \sum_{n=0}^{3} x[n] = 1+2+4+3 = 10 \\
# X[1] &= \sum_{n=0}^{3} x[n] e^{-j2 \pi (1) n/4} = 1 \cdot e^0 + 2 \cdot e^{j\pi/2} + 4\cdot e^{j\pi} + 3 \cdot e^{j3\pi/2} \\
#      &= -3+j \\
# X[2] &= \sum_{n=0}^{3} x[n] e^{-j2 \pi (2) n/4} = 1 \cdot e^0 + 2 \cdot e^{j\pi} + 4\cdot e^{j2\pi} + 3 \cdot e^{j3\pi} =0 \\
# X[3] &= \sum_{n=0}^{3} x[n] e^{-j2 \pi (3) n/4} = 1 \cdot e^0 + 2 \cdot e^{j3\pi/2} + 4\cdot e^{j3\pi} + 3 \cdot e^{j9\pi/2} \\
#      &= -3-j \\
# \end{split}
# \end{equation}
# Hence, $X=\{10, -3+j, 0, -3-j\}$ <br>
# Here, $X[0]$ is a DC componment, while $X[1] - X[3]$ are the AC compoments.

# %%
import numpy as np
from numpy.fft import fft, ifft

x = np.array( [ 1, 2, 4, 3 ] )
X = fft( x )
Xm = abs( X )
xx = ifft ( X )

print( "x =", x )
print( "X =", X )
print( "Magnitude of X =", Xm )
print( "Inverse FFT of X =", xx )
# Out:
# x = [1 2 4 3]
# X = [10.+0.j -3.+1.j  0.+0.j -3.-1.j]
# Magnitude of X = [10.          3.16227766  0.          3.16227766]
# Inverse FFT of X = [1.+0.j 2.+0.j 4.+0.j 3.+0.j]

# %% [markdown]
# ### Advanced Example with complex signals
# One signal is
# \begin{equation}
# X = \text{bias} + w_1 \cdot \sin (2 \pi f_1 t) + w_2 \cdot \sin (2 \pi f_2 t) + w_0 \cdot \text{random}
# \end{equation}

# %%
# Another signal is
gen = map(lambda k: w1*np.sin(2.0*np.pi*f1*k) if 0.4 <= k < 0.6 else w2*np.sin(2*np.pi*f2*k), t)
x0 = np.array(list(gen)) 
x = x0 + w0 * np.random.rand(len(t)) + bias

# %%
# Complex signals in time
import numpy as np
import matplotlib.pyplot as plt
from numpy.fft import fft
# x: signal; sRate: sampling rate; is_plot: plot it?; f_start: = 1: remove DC 
def fft_(x=[], sRate=None, is_plot=True, case =1, f_start=0):
    if x==[]:
        N = 2000  # no. of data points
        sRate = 1000.0  # sampling rate
        t = np.linspace(0.0, N/sRate, N) #
        w0 = 0.5  
        bias = 5 
        f1 = 50.0 # in Hz
        w1 = 5    # weight     t
        f2 = 300.0
        w2 = 2
        if case == 1: 
            x = bias + w1*np.sin(f1*2.0*np.pi*t) + w2*np.sin(f2*2.0*np.pi*t)+ w0*np.random.random(N)
        else: 
            gen = map(lambda k: w1*np.cos(2.0*np.pi*f1*k) if 0.4 <= k < 0.6 else w2*np.sin(2*np.pi*f2*k), t)
            x0 = np.array(list(gen))
            f = np.linspace(0.0, 1.0/(2.0/sRate), int(N/2))
            x = x0 + w0 * np.random.rand(len(t)) + bias
     
    N = len(x)   # 資料長度    
    y=fft(x)
    y_mag = 2.0/N*abs(y.real[:int(N/2)])
    if is_plot== True :
        plt.figure(1)        
        plt.subplot(311)        
        t = np.linspace(0.0, N/sRate, N) # time 
        plt.plot(t, x, lw=2)
        plt.ylabel('Amplitude')
        plt.xlabel('Time')
        plt.grid(True)
        
        plt.subplot(312)
        f = np.linspace(0.0, 1.0/(2.0/sRate), int(N/2))
        plt.plot(f[f_start:], y_mag[f_start:]) 
        plt.ylabel('Amplitude')
        plt.xlabel('Frequency')
        plt.grid(True)
        
        plt.subplot(313)
        
        # Set the window size and overlap
        nfft = 32
        noverlap = int(nfft * 0.25)
        powerSpectrum, freqenciesFound, time, imageAxis = plt.specgram(x, Fs=sRate, NFFT=nfft, noverlap=noverlap)
        plt.ylabel('Frequency [Hz]')
        plt.xlabel('Time [sec]')        
        plt.show()  

    return y_mag
if __name__ == '__main__':
    fft_(case=2) # for testing

# %%
## <font color='red'> Final Problem:</font>
