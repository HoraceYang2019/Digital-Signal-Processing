# %% [markdown]
# ## <font color='blue'>1. Introduction</font>

# %% [markdown]
# Preinstall: pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install

# %% [markdown]
# ## <font color='blue'>Problems</font>

# %% [markdown]
# 1. How active noise cancellation works in headphones?
# https://www.youtube.com/watch?v=F7D_pnaexG0

# %% [markdown]
# 2. Bose develops noise-cancelling technology for cars
# https://www.youtube.com/watch?time_continue=90&v=1BqTwNa4EGY&feature=emb_logo
# https://www.youtube.com/watch?v=zj33WAODsJg

# %% [markdown]
# ### <font color='green'>Next: Analog Signals</font>

# %% [markdown]
# ### Data vs. Signal
#
# - Data: information formatted in human/machine readable form, examples: voice, music, image, file

# %% [markdown]
# - Signal: electric or electromagnetic representation of data transmission media work by conducting energy along a physical  path;
# thus, to be transmitted, data must be turned into energy in  the form of electro-magnetic signals.

# %% [markdown]
# - Transmission: communication of data through propagation and  processing of signals.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <font color='blue'>Objective:</font>
# 1. What is a signal and what is a system
# 2. Why mathematical models are appropriate
# 3. What are continuous-time and discrete-time representations and how are they related

# %% [markdown]
# ### 1.1 What is a signal?

# %% [markdown]
# A signal is a pattern of variation of some form Signals are variables that carry information.
#
# Examples of signal include:
# 1. Electrical signals
# 2. Voltages and currents in a circuit
# 3. Acoustic signals
# 4. Acoustic pressure (sound) over time
# 5. Mechanical signals
# 6. Velocity of a car over time
# 7. Video signals
# 8. Intensity level of a pixel (camera, video) over time
#
# ### 訊號(Signals)可以定義為：「隨著時間改變的物理量」

# %% [markdown]
# <div><img src="attachment:image.png" width="600"/> </div>

# %% [markdown]
# <div><img src="attachment:image.png" width="300"/> </div>

# %% [markdown]
# <div><img src="attachment:image.png" width="500"/> </div>

# %% [markdown]
# ### Signal Representation- typically in 2D space, as a function of time, space or frequency
# when horizontal axis is time, graph displays  the value of a signal at one particular point  in space as a function of time
# when horizontal axis is space, graph displays  the value of a signal at one particular point in  time as a function of space

# %% [markdown]
# <div><img src="attachment:image.png" width="800"/> </div>

# %% [markdown]
# <div><img src="attachment:fe794064-1362-47ee-b2c8-fc0c8908dc5c.png" width="600"/> </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.2 How is Signal Represented with System?

# %% [markdown]
# #### <font color='blue'>Continuous & Discrete-Time Signals</font>

# %% [markdown]
# Continuous-Time Signals:
# Most signals in the real world are continuous time, as the scale is infinitesimally fine.
# Eg voltage, velocity,
# Denote by x(t), where the time interval may be bounded (finite) or infinite.

# %% [markdown]
# #### <font color='blue'>Discrete-Time Signals</font>

# %% [markdown]
# Some real world and many digital signals are discrete time, as they are sampled
# E.g. pixels, daily stock price (anything that a digital computer processes)
# Denote by $x[n]$, where $n$ is an integer value that varies discretely
# Sampled continuous signal $x[n] =x(nk) – k$ is sample time

# %% [markdown]
# <div><img src="attachment:image.png" width="500"/> </div>

# %% [markdown]
# ### 1.2.1 <font color='green'>Signal Properties</font>

# %% [markdown]
# we shall be particularly interested in signals with certain properties:
# Periodic signals: a signal is periodic if it repeats itself after a fixed period T, i.e. $x(t) = x(t+T)$ for all $t$.  <br>
# * A $\sin(t)$ signal is periodic. <br>
#
# * Even and odd signals: a signal is even if $x(-t) = x(t)$ (i.e. it can be reflected in the axis at zero).  <br>
#     A signal is odd if $x(-t) = -x(t)$.  Examples are $\cos(t)$ and $\sin(t)$ signals, respectively.
#
# * Exponential and sinusoidal signals: a signal is (real) exponential if it can be represented as $x(t) = Ce^{at}$.  <br>
#     A signal is (complex) exponential if it can be represented in the same form  but C and a are complex numbers.
#
# * Step and pulse signals: A pulse signal is one which is nearly completely zero, apart from a short spike, $d(t)$.  <br>
#     A step signal is zero up to a certain time, and then a constant value after that time, $u(t)$.

# %% [markdown]
# ### 1.2.2 <font color='green'>What is a System?</font>

# %% [markdown]
# Systems process input signals to produce output signals
#
# Examples: <br>
#
#     * A circuit involving a capacitor can be viewed as a system that transforms the source voltage (signal) to the voltage (signal) across the capacitor
#
#     * A CD player takes the signal on the CD and transforms it into a signal sent to the loud speaker
#
#     * A communication system is generally composed of three sub-systems, the transmitter, the channel and the receiver.  The channel typically attenuates and adds noise to the transmitted signal which must be processed by the receiver

# %% [markdown]
# #### 系統(Systems)可以定義為：「根據輸入訊號，經過處理或運算，藉以產生輸出訊號的實體」。

# %% [markdown]
# ### <font color='green'>1.2.3 How is a System Represented?</font>

# %% [markdown]
# A system takes a signal as an input and transforms it into another signal

# %% [markdown]
# <div><img src="attachment:image.png" width="400"/> </div>

# %% [markdown]
# In a very broad sense, a system can be represented as the ratio of the output signal over the input signal
#
# That way, when we “multiply” the system by the input signal, we get the output signal

# %% [markdown]
# #### <font color='blue'>Properties of a System</font>

# %% [markdown]
# we shall be particularly interested in signals with certain properties:
# Causal: a system is causal if the output at a time, only depends on input values up to that time.
# Linear: a system is linear if the output of the scaled sum of two input signals is the equivalent scaled sum of outputs
# Time-invariance: a system is time invariant if the system’s output is the same, given the same input signal, regardless of time.

# %% [markdown]
# #### <font color='blue'>How Are Signal & Systems Related (i)?</font>

# %% [markdown]
# a. How to design a system to process a signal in particular ways?
#
# * Design a system to restore or enhance a particular signal Remove high frequency background communication noise Enhance noisy images from spacecraft <br>
#
# * Assume a signal is represented as
# $x(t) = d(t) + n(t)$
# Design a system to remove the unknown “noise” component $n(t)$, so that $y(t) \approx d(t)$

# %% [markdown]
# <div><img src="attachment:image.png" width="400"/> </div>

# %% [markdown]
# b. How to design a system to extract specific pieces of information from signals
#
# * Estimate the heart rate from an electrocardiogram <br>
# Estimate economic indicators (bear, bull) from stock market values
#
# * Assume a signal is represented as
# $x(t) = g(d(t))$
# Design a system to “invert” the transformation $g()$, so that $y(t) = d(t)$

# %% [markdown]
# <div><img src="attachment:image.png" width="400"/> </div>

# %% [markdown]
# c. How to design a (dynamic) system to modify or control the output of another (dynamic) system <br>
#
# * Control an aircraft’s altitude, velocity, heading by adjusting throttle, rudder, ailerons <br>
# Control the temperature of a building by adjusting the heating/cooling energy flow.
#
# * Assume a signal is represented as
# $x(t) = g(d(t))$
# Design a system to “invert” the transformation $g()$, so that $y(t) = d(t)$

# %% [markdown]
# <div><img src="attachment:image.png" width="300"/> </div>

# %% [markdown]
# #### <font color='blue'> ex1. Signals in an Electrical Circuit </font>

# %% [markdown]
# The signals $v_c$ and $v_s$ are patterns of variation over time
# <div><img src="attachment:image.png" width="300"/> </div>

# %% [markdown]
# \begin{equation*}
# \begin{split}
# i(t) = \frac{v_s(t)-v_c(t)}{R} \\
# \end{split}
# \end{equation*}

# %% [markdown]
# \begin{equation}
# \begin{split}
# i(t) = C\frac{dv_c(t)}{dt} \\
# \end{split}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \begin{split}
# \frac{dv_c(t)}{dt} + \frac{1}{RC}v_c(t) = \frac{1}{RC}v_s(t) \\
# \end{split}
# \end{equation}

# %% [markdown]
# #### <font color='blue'> ex2. Continuous & Discrete-Time Mathematical Models of Systems</font>

# %% [markdown]
# Continuous-Time Systems
# Most continuous time systems represent how continuous signals are transformed via differential equations.
# E.g. circuit, car velocity

# %% [markdown]
# \begin{equation}
# \begin{split}
# m\frac{dv(t)}{dt} + \rho v(t) &= f(t)  \\
# \end{split}
# \end{equation}
# where $m$, $v(t)$, $\rho$, and $f(t)$ are mass, velocity, damping, and force, respectively.

# %% [markdown]
# #### <font color='blue'> ex3. discrete-time system</font>

# %% [markdown]
# Discrete-Time Systems
# Most discrete time systems represent how discrete signals are transformed via difference equations
# E.g. bank account, discrete car velocity system

# %% [markdown]
# \begin{equation}
# \begin{split}
# y[n]=1.01y[n-1]+x[n] \\
# \end{split}
# \end{equation}

# %% [markdown]
# ### 1.3 Signal Processing
# Signal Processing can be classified to be two <br>
# * (1)類比訊號處理(Analog Signal Processing) <br>
# * (2)數位訊號處理(Digital Signal Processing) <br>
#
# 數位訊號處理(Digital Signal Processing)，簡稱DSP，可以定義為：「使用計算機系統，對於數位訊號進行處理或運算的技術」。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 音訊處理(Audio Processing), 音訊壓縮(Audio Compression), 音樂合成(Music Synthesis), 語音處理(Speech Processing)
# * 語音合成(Speech Synthesis), 語音辨識(Speech Recognition)
# * 影像處理(Image Processing), 視訊處理(Video Processing), 電腦視覺(Computer Vision)

# %% [markdown]
# #### <font color='blue'>1.3.1 Applications</font>
#
# * 數位通訊(Digital Communication)
# * 通訊系統(Communication System)
# * 多媒體晶片設計(Multimedia IC Design)
# * 生醫訊號處理(Biomedical Signal Processing)
# * 雷達訊號處理(Radar Signal Processing)
# * 聲納訊號處理(Sonar Signal Processing)
# * 地震訊號處理(Seismology Signal Processing)
# * 自動控制系統(Automation Control System)
# * 智慧機器人(Intelligent Robots)
# * 金融科技(Financial Technology)

# %% [markdown]
# ## <font color='blue'>Advance Study</font>
# Browning, Ella & Gibb, Rory & Glover-Kapfer, Paul & Jones, Kate. (2017). Passive acoustic monitoring in ecology and conservation. 10.13140/RG.2.2.18158.46409.
#
# Recording and processing of an acoustic signal. An emitter produces a signal, which if within detectable range is picked up by a microphone or hydrophone (A; detection radius shaded in red) and transduced into an electrical signal. In digital recorders the signal is sampled at a specified sampling rate (kHz), enabling the sound to be reconstructed in the time-amplitude domain (B). A frequency spectrum can be produced using a fast Fourier transform (FFT), which calculates the signal's frequency components and their relative amplitudes (C). Calculating FFT within a sliding window across the recording produces a spectrogram, with time shown on the x-axis, frequency on the y-axis, and with amplitude (energy) shown as colour intensity (blue to yellow) (D).
# <div>
# <img src="attachment:image.png" width="700"/>
# </div>

# %% [markdown]
# ## <font color='blue'>Advance Study</font>
# S.A. Shevchik, C. Kenel, C. Leinenbach, K. Wasmer, "Acoustic emission for in situ quality monitoring in additive manufacturing using spectral convolutional neural networks,"
# Additive Manufacturing, Vol. 21, pp. 598-604, 2018.
#
# Acoustic emission for in situ quality monitoring in additive manufacturing using spectral convolutional neural networks
# <div>
# <img src="attachment:image.png" width="700"/>
# </div>

# %% [markdown]
# The acoustic signals were recorded using a fiber Bragg grating sensor during the powder bed additive manufacturing process in a commercially available selective laser melting machine. The process parameters were intentionally tuned to invoke different processing regimes that lead to the formation of different types and concentrations of pores (1.42 ± 0.85 %, 0.3 ± 0.18 % and 0.07 ± 0.02 %) inside the workpiece.

# %% [markdown]
# Related <br>
#
# S. A. Shevchik, G. Masinelli, C. Kenel, C. Leinenbach and K. Wasmer, "Deep Learning for In Situ and Real-Time Quality Monitoring in Additive Manufacturing Using Acoustic Emission," in IEEE Transactions on Industrial Informatics, vol. 15, no. 9, pp. 5194-5203, Sept. 2019, doi: 10.1109/TII.2019.2910524.

# %% [markdown]
# ## <font color='blue'>Summary</font>
#
# 1. Signals and systems are pervasive in modern engineering courses:
# Electrical circuits
# Physical models and control systems
# Digital media (music, voice, photos, video)
#
# 2. In studying the general properties of signals and systems, you can:
# Design systems to remove noise/enhance measurement from audio and picture/video data
# Investigate stability of physical structures
# Control the performance mechanical and electrical devices
#
# This will be the foundation for studying systems and signals as a generic subject on this course.
